# %%
import pandas as pd

# %%
csv = "nationwide_publicvsprivate_grad_rates.csv"
df = pd.read_csv(csv)
df.head()
# Out:
#               Unnamed: 0    1870    1871    1872    1873    1874   1875  \
# 0  High school graduates   16000     NaN     NaN     NaN     NaN    NaN
# 1                    NaN     NaN     NaN     NaN     NaN     NaN    NaN
# 2                By type     NaN     NaN     NaN     NaN     NaN    NaN
# 3                    NaN    1890    1900    1910    1920    1930   1940
# 4               % Public  0.5004  0.6507  0.7119  0.7418  0.8873  0.936
#
#      1876       1877       1878  ...       2009       2010       2011  \
# 0     NaN        NaN        NaN  ...  3347828.0  3435022.0  3449940.0
# 1     NaN        NaN        NaN  ...        NaN        NaN        NaN
# 2     NaN        NaN        NaN  ...        NaN        NaN        NaN
# 3    1950  1960.0000  1970.0000  ...        NaN        NaN        NaN
# 4  0.8864     0.8757     0.8961  ...        NaN        NaN        NaN
#
#         2012       2013       2014       2015       2016       2017       2018
# ...

# %%
csv = "nationwide_ Grads_17yr_ old_ population.csv"
df = pd.read_csv(csv)
df.head()
# Out:
#                                           Unnamed: 0    1870  1871  1872  \
# 0  High-School Graduates as % of 17-year old popu...  0.0196   NaN   NaN
#
#    1873  1874  1875  1876  1877  1878  ...    2004   2005    2006    2007  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.7426  0.754  0.7434  0.7446
#
#      2008    2009    2010    2011    2012    2013
# 0  0.7465  0.7719  0.7976  0.7898  0.8046  0.8172
#
# [1 rows x 145 columns]

# %%
xls = "teacherchar1999_2016.xls"
df = pd.read_excel(xls)
df.head()
# Out:
#   Table 209.20. Number, highest degree, and years of teaching experience of teachers in public and private elementary and secondary schools, by selected teacher characteristics: Selected years, 1999-2000 \n              through 2015-16  \
# 0            [Standard errors appear in parentheses]
# 1                    Selected teacher characteristic
# 2                                                NaN
# 3                                                  1
# 4                                     Public schools
#
#                           Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                NaN         NaN        NaN        NaN
# 1  Number of teachers (in thousands)         NaN        NaN        NaN
# 2                          1999-2000         NaN        NaN        NaN
# 3                                  2         NaN        NaN        NaN
# 4                                NaN         NaN        NaN        NaN
#
# ...

# %%
pubschls = "pubschls.csv"
public_schools = pd.read_csv(pubschls)

# %%
public_schools.columns
# Out:
# Index(['CDSCode', 'NCESDist', 'NCESSchool', 'StatusType', 'County', 'District',
#        'School', 'Street', 'StreetAbr', 'City', 'Zip', 'State', 'MailStreet',
#        'MailStrAbr', 'MailCity', 'MailZip', 'MailState', 'Phone', 'Ext',
#        'WebSite', 'OpenDate', 'ClosedDate', 'Charter', 'CharterNum',
#        'FundingType', 'DOC', 'DOCType', 'SOC', 'SOCType', 'EdOpsCode',
#        'EdOpsName', 'EILCode', 'EILName', 'GSoffered', 'GSserved', 'Virtual',
#        'Magnet', 'YearRoundYN', 'FederalDFCDistrictID', 'Latitude',
#        'Longitude', 'AdmFName1', 'AdmLName1', 'AdmEmail1', 'AdmFName2',
#        'AdmLName2', 'AdmEmail2', 'AdmFName3', 'AdmLName3', 'AdmEmail3',
#        'LastUpDate'],
#       dtype='object')

# %%
public_schools["SOC"].unique()
# Out:
# array(['No Data', '65', '66', '60', '62', '10', '14', '13', '70', '64',
#        '09', '31', '63', '68', '08', '61', '69', '98', '67', '11', '15',
#        nan], dtype=object)

# %%
public_schools["SOCType"].unique()
# Out:
# array(['No Data', 'K-12 Schools (Public)', 'High Schools (Public)',
#        'Elementary Schools (Public)',
#        'Intermediate/Middle Schools (Public)', 'County Community',
#        'Juvenile Court Schools', 'Opportunity Schools',
#        'Adult Education Centers', 'Junior High Schools (Public)',
#        'Special Education Schools (Public)', 'State Special Schools',
#        'Alternative Schools of Choice', 'Continuation High Schools',
#        'Preschool', 'Elemen Schools In 1 School Dist. (Public)',
#        'District Community Day Schools', 'ROC/ROP',
#        'High Schools In 1 School Dist. (Public)',
#        'Youth Authority Facilities', 'Other County Or District Programs',
#        nan], dtype=object)

# %%
public_schools["GSoffered"].unique()
# Out:
# array(['No Data', 'K-12', '6-12', '9-12', 'K-8', '6-8', '7-12', '10-12',
#        'K-6', 'P-5', '5-12', 'P', 'K-4', 'K-Adult', 'P-12', '8-12', 'K-5',
#        'Adult', '5', 'K', 'K-2', '9-11', '11-12', 'P-K', 'K-1', 'K-3',
#        '3-6', '7-8', '1-4', '1-8', '1-12', '5-8', '9-Adult', '12', '7-9',
#        '3-5', 'P-3', '6-9', '8', '3-4', '1-6', '4-5', '4-6', 'P-6', '4-8',
#        '9-Post Secondary', '2-5', 'P-Adult', '2-12', 'K-9', '5-6', 'K-7',
#        'P-4', '3', '1-3', '7-10', '2-6', 'P-8', '2-3', '1', '3-8', '7-11',
#        '4-12', 'K-10', '9-10', '6', '9', '4-11', '6-11', '2-8', '6-10',
#        '3-12', '6-7', 'K-11', '1-5', '7', 'P-7', '12-Adult', 'P-1',
#        '8-10', '8-11', '3-7', 'P-2', '4', '11-Adult', '8-9', '10',
#        '7-Adult', '10-Adult', '5-9', '3-13', '2-4', '1-9', '10-11',
#        'P-Post Secondary', '1-2', nan], dtype=object)

# %%
public_schools["DOC"].unique()
# Out:
# array([ 0., 31., 42., 54., 56., 52., 58., 98.,  2., 34., 99.,  3., nan])

# %%
public_schools = public_schools[["CDSCode","NCESDist", "StatusType", "County", "District", "School", "Street", "City", "Zip","OpenDate", "ClosedDate",
                                 "Charter", "FundingType"  ]]
public_schools
# Out:
#                 CDSCode NCESDist StatusType   County  \
# 0         1100170000000  0691051     Active  Alameda
# 1         1100170109835  0691051     Closed  Alameda
# 2         1100170112607  0691051     Active  Alameda
# 3         1100170118489  0691051     Closed  Alameda
# 4         1100170123968  0691051     Active  Alameda
# ...                 ...      ...        ...      ...
# 18100    58727695830039  0642350     Closed     Yuba
# 18101    58727695830070  0642350     Closed     Yuba
# 18102    58727695830120  0642350     Closed     Yuba
# 18103    58727695838305  0642350     Active     Yuba
# 18104  Total Records =     18104        NaN      NaN
#
#                                  District  \
# 0      Alameda County Office of Education
# 1      Alameda County Office of Education
# 2      Alameda County Office of Education
# 3      Alameda County Office of Education
# 4      Alameda County Office of Education
# ...                                   ...
# ...

# %%
public_schools["FundingType"].unique()
# Out:
# array(['No Data', 'Directly funded', 'Locally funded',
#        'Not in CS funding model', nan], dtype=object)

# %%
public_schools["StatusType"].unique()
# Out:
# array(['Active', 'Closed', 'Merged', 'Pending', nan], dtype=object)
