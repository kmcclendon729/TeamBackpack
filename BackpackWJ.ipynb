# %%
import pandas as pd

# %%
# Reference to CSV and reading CSV into Pandas DataFrame
keyword_csv = "JungleScoutkeyword.csv"
keyword_data = pd.read_csv(keyword_csv, skiprows = 3)
keyword_data.head()
# Out:
#                       Keyword   30-Day Search Volume (Exact)  30 Day Trend  \
# 0                   backpack                          110920          -43%
# 1   backpack purse for women                           40461          -46%
# 2              mini backpack                           33614          -30%
# 3         backpack for women                           31575          -50%
# 4  tactical backpack for men                           27181           38%
#
#    90 Day Trend   30-Day Search Volume (Broad)          Dominant Category  \
# 0           -8%                         654963           Laptop Backpacks
# 1           43%                          55365  Clothing, Shoes & Jewelry
# 2          -14%                          78307  Clothing, Shoes & Jewelry
# 3           -4%                         165376  Clothing, Shoes & Jewelry
# 4          233%                          29508          Sports & Outdoors
#
#     Recommended Promotions  Sp. Brand Ad Bid  PPC Bid (Exact)  \
# ...

# %%
search_csv = "SearchTermbackpack.csv"
search_term = pd.read_csv(search_csv)
search_term.head()
# Out:
#   Export date: 5/14/2020, 12:12:44 PM  Unnamed: 1  #  \
# 0               Search Term: backpack         NaN  1
# 1                  Average Sales: 896         NaN  2
# 2          Average Sales Rank: 25,467         NaN  3
# 3               Average Price: $42.11         NaN  4
# 4              Average Reviews: 1,709         NaN  5
#
#                                         Product Name    Brand   Price  \
# 0  Travel Laptop Backpack Business Anti Theft Sli...   MATEIN  $29.99
# 1  PANS Backpack Large Military Expandable Travel...    Feeke  $37.99
# 2  Travel Laptop Backpack Business Anti Theft Sli...   MATEIN  $29.99
# 3  Backpacks for Men Extra Large Travel Laptop Ba...  YOREPEK  $33.99
# 4  Modoker Vintage Laptop Backpack for Women MenS...  Modoker  $23.99
#
#    Mo. Sales Mo. Revenue  Date First Available     Net  Reviews  Rating  \
# 0    11269.0     $337957                   NaN  $20.76    14259     4.5
# 1     3183.0     $120922                   NaN  $27.06     1251     4.5
# ...

# %%
export_csv = "JungleScoutCSVExport.csv"
jsexport = pd.read_csv(export_csv, skiprows = 2)
jsexport.head()
# Out:
#          ASIN                                       Product Name   \
# 0  B07W7V2WJK   Husqvarna 965877502 350BT 2-Cycle Gas Backpack...
# 1  B07YGVYQ9P   D.B. Smith Field King Professional 190328 No L...
# 2  B07P13Q9PT   Roc Inflatable Stand Up Paddle Board W Free Pr...
# 3  B07ZJWGSFG   Roc Inflatable Stand Up Paddle Board W Free Pr...
# 4  B07ZJWVY71   Roc Inflatable Stand Up Paddle Board W Free Pr...
#
#         Brand               Category  Est. Monthly Revenue   \
# 0   Husqvarna   Patio, Lawn & Garden         $1,835,946.00
# 1  D.B. Smith   Patio, Lawn & Garden           $810,000.00
# 2         Roc      Sports & Outdoors           $803,580.45
# 3         Roc      Sports & Outdoors           $798,056.10
# 4         Roc      Sports & Outdoors           $796,781.25
#
#   Est. Monthly Sales       Price      Fees       Net    Rank  Reviews   LQS   \
# 0              1,800   $1,019.97   $157.71   $862.26   1,860      915      3
# ...
